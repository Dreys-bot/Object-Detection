# %%
# !pip install torch

# %%
# !pip install ipywidgets

# %%
import torch #yolov5 implemented using pytorch
from IPython.display import Image #this is to render predictions

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# C:\Users\audre\Documents\yolov5_test\yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.30-py3-none-any.whl (184 kB)
# ...
#   Using cached opencv_python-4.7.0.68-cp37-abi3-win_amd64.whl (38.2 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# ...
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# ...

# %%
# !pip install IProgress
# Out:
# ...
#   Using cached IProgress-0.4-py3-none-any.whl (11 kB)
# ...

# %%
from tqdm import tqdm
import IProgress
from ipywidgets import IntProgress

# %%
#!python train.py --img 416 --batch 16 --epochs 50 --data dataset.yaml --weights yolov5s.pt --cache

# %% [markdown]
# ## Testing Model

# %%
#! python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source runs/train/exp2/test_images

# %% [markdown]
# ## Step 1: yolov5(.pt model) -> .pb model
#
# ## .pb model -> .tflite model
#
# ## Use tflite model in Android App

# %% [markdown]
# ## Yolov5 model is trained and tested.
# ## Now next step is to convert it into a tflite model, so that we can use it on android phone

# %%
# !python export.py --weights runs/train/exp/weights/best.pt --include tflite --img 416
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(1, 416, 416, 3)]   0           []
#
#  tf_conv (TFConv)               (1, 208, 208, 32)    3488        ['input_1[0][0]']
#
#  tf_conv_1 (TFConv)             (1, 104, 104, 64)    18496       ['tf_conv[0][0]']
#
#  tfc3 (TFC3)                    (1, 104, 104, 64)    18624       ['tf_conv_1[0][0]']
#
#  tf_conv_7 (TFConv)             (1, 52, 52, 128)     73856       ['tfc3[0][0]']
#
#  tfc3_1 (TFC3)                  (1, 52, 52, 128)     115200      ['tf_conv_7[0][0]']
#
#  tf_conv_15 (TFConv)            (1, 26, 26, 256)     295168      ['tfc3_1[0][0]']
#
#  tfc3_2 (TFC3)                  (1, 26, 26, 256)     623872      ['tf_conv_15[0][0]']
#
#  tf_conv_25 (TFConv)            (1, 13, 13, 512)     1180160     ['tfc3_2[0][0]']
#
# ...

# %%
#After running the above command, you will have best-fp16.tflite in runs\train\exp2\weights folder

# Lets run the created tflite model.

# !python detect.py --weights runs\train\exp\weights\best-fp16.tflite --img 416 --conf 0.25 --source runs\train\exp\test_images\test\images
# Out:
# detect: weights=['runs\\train\\exp\\weights\\best-fp16.tflite'], source=runs\train\exp\test_images\test\images, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2023-1-3 Python-3.9.12 torch-1.13.1+cpu CPU
#
# Loading runs\train\exp\weights\best-fp16.tflite for TensorFlow Lite inference...
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# image 1/142 C:\Users\audre\Documents\yolov5_test\yolov5\runs\train\exp\test_images\test\images\107_jpg.rf.0f6459081ce7ed174a8fedf6af3c69bc.jpg: 416x416 1 train, 241.4ms
# ...

# %%
# !conda install tensorflow=1.14

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'C:\\Users\\audre\\Downloads\\model_lite_gender.h5')
tfmodel = converter.convert()
open ("gender.tflite" , "wb") .write(tfmodel)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 from tensorflow.contrib import lite
#       2 converter = lite.TFLiteConverter.from_keras_model_file( 'C:\\Users\\audre\\Downloads\\model_lite_gender.h5')
#       3 tfmodel = converter.convert()
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'
